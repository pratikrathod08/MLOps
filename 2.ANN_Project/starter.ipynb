# %% [markdown]
# ### Quickstart : Compare runs, choose a model, and deploy it to a REST API.

# %% [markdown]
# In this quickstart :
#
# 1. Run a hyperparameter sweep on a training script.
# 2. Compare the results of runs in the MLFlow UI.
# 3. Choose the best run and register it as a model.
# 4. Deploy the model to a rest api.
# 5. Build a container image suitable for deployment to a cloud platform.

# %%
## Import libraries 

import keras 
import numpy as np 
import pandas as pd 
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split 

import mlflow 
from mlflow.models import infer_signature

# %%
## load the dataset
data=pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.0              0.27         0.36  ...       0.45      8.8        6
# 1               6.3              0.30         0.34  ...       0.49      9.5        6
# 2               8.1              0.28         0.40  ...       0.44     10.1        6
# 3               7.2              0.23         0.32  ...       0.40      9.9        6
# 4               7.2              0.23         0.32  ...       0.40      9.9        6
# ...             ...               ...          ...  ...        ...      ...      ...
# 4893            6.2              0.21         0.29  ...       0.50     11.2        6
# 4894            6.6              0.32         0.36  ...       0.46      9.6        5
# 4895            6.5              0.24         0.19  ...       0.46      9.4        6
# 4896            5.5              0.29         0.30  ...       0.38     12.8        7
# 4897            6.0              0.21         0.38  ...       0.32     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Split the data into training validation and test 

train, test = train_test_split(data, test_size=0.20, random_state=42)

# %%
train
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 4665            7.3              0.17         0.36  ...       0.41     12.4        6
# 1943            6.3              0.25         0.44  ...       0.52      9.5        5
# 3399            5.6              0.32         0.33  ...       0.49     11.1        6
# 843             6.9              0.19         0.35  ...       0.54     10.8        7
# 2580            7.7              0.30         0.26  ...       0.50     10.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 4426            6.2              0.21         0.52  ...       0.49      9.9        6
# 466             7.0              0.14         0.32  ...       0.43      9.4        6
# 3092            7.6              0.27         0.52  ...       0.53     11.4        6
# 3772            6.3              0.24         0.29  ...       0.38     10.6        6
# 860             8.1              0.27         0.35  ...       0.63     10.4        8
#
# [3918 rows x 12 columns]

# %%
## Training Data 
train_x = train.drop(columns=['quality'], axis=1).values
train_y = train[['quality']].values.ravel()

## Validation Data 
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.20, random_state=42)

## Test set 
test_x = test.drop(columns=['quality'], axis=1).values
test_y = test[['quality']].values.ravel()

signature = infer_signature(train_x, train_y)

# %%
## ANN Model Creation 

def train_model(params, epochs, train_x, train_y, valid_x, valid_y, test_x, test_y):

    ## Define model architecture 
    mean = np.mean(train_x, axis=0)
    var = np.var(train_x, axis=0)

    model=keras.Sequential(
        [
            keras.Input(shape=(train_x.shape[1], ) ), 
            keras.layers.Normalization(mean=mean, variance=var), 
            keras.layers.Dense(64, activation='relu'), 
            keras.layers.Dense(1)
        ]
    )

    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params['lr'], 
        momentum=params['momentum'], 
    ), 
    loss="mean_squared_error", 
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN Model with lr and momentum parameters with mlflow tracking 
    with mlflow.start_run(nested=True):
        model.fit(train_x, train_y, 
          validation_data=(valid_x, valid_y),  # Ensure correct tuple format
          epochs=epochs, 
          batch_size=64)
        
        ## Evaluate model 
        eval_result = model.evaluate(valid_x, valid_y, batch_size=64)

        eval_rmse = eval_result[1]

        ## Log the parameters and results 
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        mlflow.tensorflow.log_model(model, "model", signature=signature)

        return {
            "loss": eval_rmse, "status": STATUS_OK, "model": model
        }

# %%
def objective(params):
    ## MLFlow will track the params and results for each run 
    result = train_model(
        params, 
        epochs=3, 
        train_x=train_x, 
        train_y=train_y, 
        valid_x=val_x, 
        valid_y=val_y, 
        test_x=test_x, 
        test_y=test_y
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr", np.log(1e-5), np.log(1e-1)),
    "momentum":hp.uniform("momentum", 0.0, 1.0) 
}

# %%
mlflow.set_experiment("/wine-quality")
with mlflow.start_run():
    ## Hyperparameter search using hyperopt 
    trials= Trials()
    best= fmin(
        fn=objective, 
        space=space, 
        algo=tpe.suggest,
        max_evals=4, 
        trials=trials
    )

    ## Fetch details of the best run 
    best_run = sorted(trials.results, key=lambda x:x["loss"])[0]

    ## Log the best parameters, loss and model 
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run['loss'])
    mlflow.tensorflow.log_model(best_run['model'], 'model', signature=signature)

    ## Print out best parameters and corresponding loss 
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# Epoch 1/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 22s 474ms/step - loss: 32.7199 - root_mean_squared_error: 5.7201
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.7518 - root_mean_squared_error: 5.5445
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30.1580 - root_mean_squared_error: 5.4902 - val_loss: 24.1871 - val_root_mean_squared_error: 4.9180
#
# Epoch 2/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 23.6202 - root_mean_squared_error: 4.8601
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22.2024 - root_mean_squared_error: 4.7114
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.9390 - root_mean_squared_error: 4.6831 - val_loss: 17.8803 - val_root_mean_squared_error: 4.2285
#
# Epoch 3/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 17.5309 - root_mean_squared_error: 4.1870
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 16.6237 - root_mean_squared_error: 4.0761
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.3574 - root_mean_squared_error: 4.0430 - val_loss: 13.3185 - val_root_mean_squared_error: 3.6495
#
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 12.9289 - root_mean_squared_error: 3.5957
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.1337 - root_mean_squared_error: 3.6236
#
# Epoch 1/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 18s 379ms/step - loss: 35.9082 - root_mean_squared_error: 5.9923
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.1347 - root_mean_squared_error: 5.9273
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 34.9638 - root_mean_squared_error: 5.9128 - val_loss: 31.7966 - val_root_mean_squared_error: 5.6389
#
# Epoch 2/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 30.3034 - root_mean_squared_error: 5.5048
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.4611 - root_mean_squared_error: 5.5189
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.3060 - root_mean_squared_error: 5.5048 - val_loss: 27.1426 - val_root_mean_squared_error: 5.2099
#
# Epoch 3/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 27.6096 - root_mean_squared_error: 5.2545
# 39/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26.3514 - root_mean_squared_error: 5.1330
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.0885 - root_mean_squared_error: 5.1072 - val_loss: 23.2158 - val_root_mean_squared_error: 4.8183
#
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 22.4243 - root_mean_squared_error: 4.7354
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.0304 - root_mean_squared_error: 4.7988
#
# Epoch 1/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 14s 311ms/step - loss: 35.8970 - root_mean_squared_error: 5.9914
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.8395 - root_mean_squared_error: 5.9853
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 35.7875 - root_mean_squared_error: 5.9809 - val_loss: 28.4013 - val_root_mean_squared_error: 5.3293
#
# Epoch 2/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 27.3577 - root_mean_squared_error: 5.2305
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26.0996 - root_mean_squared_error: 5.1080
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.7918 - root_mean_squared_error: 5.0774 - val_loss: 20.4270 - val_root_mean_squared_error: 4.5196
#
# Epoch 3/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 20.0253 - root_mean_squared_error: 4.4750
# 46/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 18.6850 - root_mean_squared_error: 4.3217
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.5709 - root_mean_squared_error: 4.3083 - val_loss: 14.6436 - val_root_mean_squared_error: 3.8267
#
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 14.2150 - root_mean_squared_error: 3.7703
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.6255 - root_mean_squared_error: 3.8242
#
# Epoch 1/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 14s 304ms/step - loss: 41.2995 - root_mean_squared_error: 6.4265
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28.8833 - root_mean_squared_error: 5.3511
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 28.5657 - root_mean_squared_error: 5.3201 - val_loss: 9.6427 - val_root_mean_squared_error: 3.1053
#
# Epoch 2/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.8756 - root_mean_squared_error: 2.9792
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9908 - root_mean_squared_error: 2.6372
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7903 - root_mean_squared_error: 2.5975 - val_loss: 3.5189 - val_root_mean_squared_error: 1.8759
#
# Epoch 3/3
#
#  1/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.6324 - root_mean_squared_error: 1.6225
# 47/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6494 - root_mean_squared_error: 1.6271
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6368 - root_mean_squared_error: 1.6232 - val_loss: 2.5560 - val_root_mean_squared_error: 1.5988
#
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.0187 - root_mean_squared_error: 1.7374
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6633 - root_mean_squared_error: 1.6313
#
# 100%|██████████| 4/4 [00:43<00:00, 10.87s/trial, best loss: 1.5987533330917358]
# Best parameters: {'lr': np.float64(0.0006033202908572407), 'momentum': np.float64(0.5999704330019584)}
# Best eval rmse: 1.5987533330917358
